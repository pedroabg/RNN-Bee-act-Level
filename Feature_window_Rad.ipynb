# %%
import numpy
import matplotlib.pyplot as plt
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.recurrent import GRU
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import pandas
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import aux_func as f
# Out:
# Using Theano backend.

# %%
feature_dim = 1
look_back = 0
data_file = 'abelha-only-rad.csv'
data_use_percent = 1

# fix random seed for reproducibility
#numpy.random.seed(7)

# load the dataset
dataframe = pandas.read_csv(data_file, engine='python')

def create_window(data, feature_name, past_times =[]):
    index = [feature_name]
    dataframe = data.copy()
    for i in past_times:
        dataframe[feature_name+'_t-'+str(i)] = dataframe[feature_name].shift(periods=i, freq=None, axis=0)
        index.append(feature_name+'_t-'+str(i))
    index.append('act')
    
    return dataframe.tail(-max(window)).reindex_axis(index,axis=1)

def normalize(dataframe):
    old_act = dataframe['act']
    dataframe2 = (dataframe - dataframe.min())/(dataframe.max() - dataframe.min())
    dataframe2['act'] = old_act
    return dataframe2

def train_predict(dataframe, times = 1):
    dataset2 = dataframe.values
    #resizing dataset len for faster tests 
    dataset2 = dataset2[:int(len(dataset2)*data_use_percent)]
    dataset2 = dataset2.astype('float32')

    # split into train and test sets
    train_size = int(len(dataset2) * 0.70)
    test_size = len(dataset2) - train_size
    train, test = dataset2[0:train_size,:], dataset2[train_size:len(dataset2),:]

    

    trainX, trainY = f.create_dataset(train, feature_dim, look_back)
    testX, testY = f.create_dataset(test, feature_dim, look_back)

    # reshape input to be [samples, time steps, features]
    trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))


    for i in range(times):
        model = f.baseline_model(feature_dim + look_back)
        model.fit(trainX, trainY, nb_epoch=500, verbose=0)

        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)
        trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
        print(str(i)+' Train Score: %.6f RMSE' % (trainScore))
        testScore = math.sqrt(mean_squared_error(testY, testPredict))
        print(str(i)+' Test Score: %.6f RMSE' % (testScore))

    f.g_plot(dataset2,trainPredict, testPredict, feature_dim, look_back)
    

dataframe.head(8), feature_dim
# Out:
# (      rad    act
#  0   -3.54  0.023
#  1   -3.54  0.028
#  2   -3.54  0.092
#  3   -3.54  0.161
#  4   33.98  0.276
#  5  154.70  0.618
#  6  297.80  1.060
#  7  817.20  1.240, 1)

# %%
dataframe1 = normalize(dataframe)
dataframe1
# Out:
#           rad    act
# 0    0.000000  0.023
# 1    0.000000  0.028
# 2    0.000000  0.092
# 3    0.000000  0.161
# 4    0.011469  0.276
# 5    0.048369  0.618
# 6    0.092110  1.060
# 7    0.250873  1.240
# 8    0.739878  1.217
# 9    0.892711  1.346
# 10   0.990219  1.207
# 11   0.955678  1.166
# 12   0.729180  1.175
# 13   0.581848  0.691
# 14   0.339149  0.581
# 15   0.063132  0.456
# 16   0.003629  0.548
# 17   0.000000  0.382
# 18   0.000000  0.060
# 19   0.000058  0.009
# 20   0.000012  0.046
# 21   0.000006  0.005
# 22   0.000000  0.037
# 23   0.000000  0.065
# 24   0.000000  0.019
# 25   0.000000  0.019
# 26   0.000000  0.019
# 27   0.000000  0.019
# 28   0.010967  0.019
# 29   0.038312  0.876
# ..        ...    ...
# 714  0.000000  0.087
# 715  0.000000  0.013
# 716  0.000000  0.020
# 717  0.000000  0.094
# 718  0.000000  0.087
# 719  0.000000  0.127
# 720  0.000000  0.155
# 721  0.000000  0.163
# 722  0.000000  0.167
# 723  0.000000  0.242
# 724  0.015195  0.500
# 725  0.055857  0.875
# 726  0.084468  1.352
# 727  0.201630  1.598
# 728  0.704421  2.458
# 729  0.607830  2.015
# 730  0.668046  1.280
# 731  0.443687  1.269
# 732  0.267562  1.049
# 733  0.238677  1.038
# 734  0.135606  0.648
# 735  0.042530  0.288
# 736  0.002080  0.258
# 737  0.000587  0.110
# 738  0.000614  0.015
# 739  0.000300  0.000
# 740  0.000012  0.004
# 741  0.000089  0.004
# 742  0.000223  0.008
# 743  0.000037  0.000
#
# [744 rows x 2 columns]

# %%
train_predict(dataframe1,10)
# Out:
# 0 Train Score: 0.294521 RMSE
# 0 Test Score: 0.276517 RMSE
# 1 Train Score: 0.292478 RMSE
# 1 Test Score: 0.281402 RMSE
# 2 Train Score: 0.292788 RMSE
# 2 Test Score: 0.279523 RMSE
# 3 Train Score: 0.303202 RMSE
# 3 Test Score: 0.264950 RMSE
# 4 Train Score: 0.293412 RMSE
# 4 Test Score: 0.278721 RMSE
# 5 Train Score: 0.294759 RMSE
# 5 Test Score: 0.273767 RMSE
# 6 Train Score: 0.293377 RMSE
# 6 Test Score: 0.276024 RMSE
# 7 Train Score: 0.293221 RMSE
# 7 Test Score: 0.280731 RMSE
# 8 Train Score: 0.292778 RMSE
# 8 Test Score: 0.279289 RMSE
# 9 Train Score: 0.295292 RMSE
# 9 Test Score: 0.277560 RMSE

# %%
window = [3]
dataframe1 = normalize(dataframe)
dataframe1 = create_window(dataframe1, "rad", window)
feature_dim = len(window) + 1
dataframe1, feature_dim
# Out:
# (          rad   rad_t-3    act
#  3    0.000000  0.000000  0.161
#  4    0.011469  0.000000  0.276
#  5    0.048369  0.000000  0.618
#  6    0.092110  0.000000  1.060
#  7    0.250873  0.011469  1.240
#  8    0.739878  0.048369  1.217
#  9    0.892711  0.092110  1.346
#  10   0.990219  0.250873  1.207
#  11   0.955678  0.739878  1.166
#  12   0.729180  0.892711  1.175
#  13   0.581848  0.990219  0.691
#  14   0.339149  0.955678  0.581
#  15   0.063132  0.729180  0.456
#  16   0.003629  0.581848  0.548
#  17   0.000000  0.339149  0.382
#  18   0.000000  0.063132  0.060
#  19   0.000058  0.003629  0.009
#  20   0.000012  0.000000  0.046
#  21   0.000006  0.000000  0.005
#  22   0.000000  0.000058  0.037
#  23   0.000000  0.000012  0.065
#  24   0.000000  0.000006  0.019
#  25   0.000000  0.000000  0.019
#  26   0.000000  0.000000  0.019
#  27   0.000000  0.000000  0.019
#  28   0.010967  0.000000  0.019
#  29   0.038312  0.000000  0.876
#  30   0.055032  0.000000  1.329
#  31   0.207682  0.010967  1.314
#  32   0.772584  0.038312  1.433
#  ..        ...       ...    ...
#  714  0.000000  0.035867  0.087
#  715  0.000000  0.001448  0.013
#  716  0.000000  0.000000  0.020
#  717  0.000000  0.000000  0.094
#  718  0.000000  0.000000  0.087
#  719  0.000000  0.000000  0.127
#  720  0.000000  0.000000  0.155
#  721  0.000000  0.000000  0.163
#  722  0.000000  0.000000  0.167
#  723  0.000000  0.000000  0.242
#  724  0.015195  0.000000  0.500
#  725  0.055857  0.000000  0.875
#  726  0.084468  0.000000  1.352
#  727  0.201630  0.015195  1.598
#  728  0.704421  0.055857  2.458
#  729  0.607830  0.084468  2.015
#  730  0.668046  0.201630  1.280
#  731  0.443687  0.704421  1.269
#  732  0.267562  0.607830  1.049
#  733  0.238677  0.668046  1.038
#  734  0.135606  0.443687  0.648
#  735  0.042530  0.267562  0.288
#  736  0.002080  0.238677  0.258
#  737  0.000587  0.135606  0.110
#  738  0.000614  0.042530  0.015
#  739  0.000300  0.002080  0.000
#  740  0.000012  0.000587  0.004
#  741  0.000089  0.000614  0.004
#  742  0.000223  0.000300  0.008
#  743  0.000037  0.000012  0.000
#
#  [741 rows x 3 columns], 2)

# %%
train_predict(dataframe1,10)
# Out:
# 0 Train Score: 0.202590 RMSE
# 0 Test Score: 0.224881 RMSE
# 1 Train Score: 0.189281 RMSE
# 1 Test Score: 0.220293 RMSE
# 2 Train Score: 0.189598 RMSE
# 2 Test Score: 0.227020 RMSE
# 3 Train Score: 0.190045 RMSE
# 3 Test Score: 0.220184 RMSE
# 4 Train Score: 0.194516 RMSE
# 4 Test Score: 0.231329 RMSE
# 5 Train Score: 0.178418 RMSE
# 5 Test Score: 0.229439 RMSE
# 6 Train Score: 0.180664 RMSE
# 6 Test Score: 0.233542 RMSE
# 7 Train Score: 0.197826 RMSE
# 7 Test Score: 0.210097 RMSE
# 8 Train Score: 0.177973 RMSE
# 8 Test Score: 0.238695 RMSE
# 9 Train Score: 0.187090 RMSE
# 9 Test Score: 0.215947 RMSE

# %%
window = [3,6]
dataframe1 = normalize(dataframe)
dataframe1 = create_window(dataframe1, "rad", window)
feature_dim = len(window) + 1
dataframe1
# Out:
#           rad   rad_t-3   rad_t-6    act
# 6    0.092110  0.000000  0.000000  1.060
# 7    0.250873  0.011469  0.000000  1.240
# 8    0.739878  0.048369  0.000000  1.217
# 9    0.892711  0.092110  0.000000  1.346
# 10   0.990219  0.250873  0.011469  1.207
# 11   0.955678  0.739878  0.048369  1.166
# 12   0.729180  0.892711  0.092110  1.175
# 13   0.581848  0.990219  0.250873  0.691
# 14   0.339149  0.955678  0.739878  0.581
# 15   0.063132  0.729180  0.892711  0.456
# 16   0.003629  0.581848  0.990219  0.548
# 17   0.000000  0.339149  0.955678  0.382
# 18   0.000000  0.063132  0.729180  0.060
# 19   0.000058  0.003629  0.581848  0.009
# 20   0.000012  0.000000  0.339149  0.046
# 21   0.000006  0.000000  0.063132  0.005
# 22   0.000000  0.000058  0.003629  0.037
# 23   0.000000  0.000012  0.000000  0.065
# 24   0.000000  0.000006  0.000000  0.019
# 25   0.000000  0.000000  0.000058  0.019
# 26   0.000000  0.000000  0.000012  0.019
# 27   0.000000  0.000000  0.000006  0.019
# 28   0.010967  0.000000  0.000000  0.019
# 29   0.038312  0.000000  0.000000  0.876
# 30   0.055032  0.000000  0.000000  1.329
# 31   0.207682  0.010967  0.000000  1.314
# 32   0.772584  0.038312  0.000000  1.433
# 33   0.928168  0.055032  0.000000  1.114
# 34   0.670492  0.207682  0.010967  0.848
# 35   0.813543  0.772584  0.038312  0.943
# ..        ...       ...       ...    ...
# 714  0.000000  0.035867  0.497484  0.087
# 715  0.000000  0.001448  0.255672  0.013
# 716  0.000000  0.000000  0.215385  0.020
# 717  0.000000  0.000000  0.035867  0.094
# 718  0.000000  0.000000  0.001448  0.087
# 719  0.000000  0.000000  0.000000  0.127
# 720  0.000000  0.000000  0.000000  0.155
# 721  0.000000  0.000000  0.000000  0.163
# 722  0.000000  0.000000  0.000000  0.167
# 723  0.000000  0.000000  0.000000  0.242
# 724  0.015195  0.000000  0.000000  0.500
# 725  0.055857  0.000000  0.000000  0.875
# 726  0.084468  0.000000  0.000000  1.352
# 727  0.201630  0.015195  0.000000  1.598
# 728  0.704421  0.055857  0.000000  2.458
# 729  0.607830  0.084468  0.000000  2.015
# 730  0.668046  0.201630  0.015195  1.280
# 731  0.443687  0.704421  0.055857  1.269
# 732  0.267562  0.607830  0.084468  1.049
# 733  0.238677  0.668046  0.201630  1.038
# 734  0.135606  0.443687  0.704421  0.648
# 735  0.042530  0.267562  0.607830  0.288
# 736  0.002080  0.238677  0.668046  0.258
# 737  0.000587  0.135606  0.443687  0.110
# 738  0.000614  0.042530  0.267562  0.015
# 739  0.000300  0.002080  0.238677  0.000
# 740  0.000012  0.000587  0.135606  0.004
# 741  0.000089  0.000614  0.042530  0.004
# 742  0.000223  0.000300  0.002080  0.008
# 743  0.000037  0.000012  0.000587  0.000
#
# [738 rows x 4 columns]

# %%
train_predict(dataframe1,10)
# Out:
# 0 Train Score: 0.171817 RMSE
# 0 Test Score: 0.230849 RMSE
# 1 Train Score: 0.172107 RMSE
# 1 Test Score: 0.223900 RMSE
# 2 Train Score: 0.173331 RMSE
# 2 Test Score: 0.227650 RMSE
# 3 Train Score: 0.173352 RMSE
# 3 Test Score: 0.206856 RMSE
# 4 Train Score: 0.187127 RMSE
# 4 Test Score: 0.213231 RMSE
# 5 Train Score: 0.175787 RMSE
# 5 Test Score: 0.219644 RMSE
# 6 Train Score: 0.174226 RMSE
# 6 Test Score: 0.213069 RMSE
# 7 Train Score: 0.180440 RMSE
# 7 Test Score: 0.241722 RMSE
# 8 Train Score: 0.169281 RMSE
# 8 Test Score: 0.220205 RMSE
# 9 Train Score: 0.170158 RMSE
# 9 Test Score: 0.215909 RMSE

# %%
window = [3,6,12]
dataframe1 = normalize(dataframe)
dataframe1 = create_window(dataframe1, "rad", window)
feature_dim = len(window) + 1
dataframe1
# Out:
#           rad   rad_t-3   rad_t-6  rad_t-12    act
# 12   0.729180  0.892711  0.092110  0.000000  1.175
# 13   0.581848  0.990219  0.250873  0.000000  0.691
# 14   0.339149  0.955678  0.739878  0.000000  0.581
# 15   0.063132  0.729180  0.892711  0.000000  0.456
# 16   0.003629  0.581848  0.990219  0.011469  0.548
# 17   0.000000  0.339149  0.955678  0.048369  0.382
# 18   0.000000  0.063132  0.729180  0.092110  0.060
# 19   0.000058  0.003629  0.581848  0.250873  0.009
# 20   0.000012  0.000000  0.339149  0.739878  0.046
# 21   0.000006  0.000000  0.063132  0.892711  0.005
# 22   0.000000  0.000058  0.003629  0.990219  0.037
# 23   0.000000  0.000012  0.000000  0.955678  0.065
# 24   0.000000  0.000006  0.000000  0.729180  0.019
# 25   0.000000  0.000000  0.000058  0.581848  0.019
# 26   0.000000  0.000000  0.000012  0.339149  0.019
# 27   0.000000  0.000000  0.000006  0.063132  0.019
# 28   0.010967  0.000000  0.000000  0.003629  0.019
# 29   0.038312  0.000000  0.000000  0.000000  0.876
# 30   0.055032  0.000000  0.000000  0.000000  1.329
# 31   0.207682  0.010967  0.000000  0.000058  1.314
# 32   0.772584  0.038312  0.000000  0.000012  1.433
# 33   0.928168  0.055032  0.000000  0.000006  1.114
# 34   0.670492  0.207682  0.010967  0.000000  0.848
# 35   0.813543  0.772584  0.038312  0.000000  0.943
# 36   0.659793  0.928168  0.055032  0.000000  1.095
# 37   0.314696  0.670492  0.207682  0.000000  0.700
# 38   0.264016  0.813543  0.772584  0.000000  0.429
# 39   0.043631  0.659793  0.928168  0.000000  0.395
# 40   0.003012  0.314696  0.670492  0.010967  0.438
# 41   0.000000  0.264016  0.813543  0.038312  0.124
# ..        ...       ...       ...       ...    ...
# 714  0.000000  0.035867  0.497484  0.098437  0.087
# 715  0.000000  0.001448  0.255672  0.208202  0.013
# 716  0.000000  0.000000  0.215385  0.750576  0.020
# 717  0.000000  0.000000  0.035867  0.911968  0.094
# 718  0.000000  0.000000  0.001448  0.649706  0.087
# 719  0.000000  0.000000  0.000000  0.624336  0.127
# 720  0.000000  0.000000  0.000000  0.497484  0.155
# 721  0.000000  0.000000  0.000000  0.255672  0.163
# 722  0.000000  0.000000  0.000000  0.215385  0.167
# 723  0.000000  0.000000  0.000000  0.035867  0.242
# 724  0.015195  0.000000  0.000000  0.001448  0.500
# 725  0.055857  0.000000  0.000000  0.000000  0.875
# 726  0.084468  0.000000  0.000000  0.000000  1.352
# 727  0.201630  0.015195  0.000000  0.000000  1.598
# 728  0.704421  0.055857  0.000000  0.000000  2.458
# 729  0.607830  0.084468  0.000000  0.000000  2.015
# 730  0.668046  0.201630  0.015195  0.000000  1.280
# 731  0.443687  0.704421  0.055857  0.000000  1.269
# 732  0.267562  0.607830  0.084468  0.000000  1.049
# 733  0.238677  0.668046  0.201630  0.000000  1.038
# 734  0.135606  0.443687  0.704421  0.000000  0.648
# 735  0.042530  0.267562  0.607830  0.000000  0.288
# 736  0.002080  0.238677  0.668046  0.015195  0.258
# 737  0.000587  0.135606  0.443687  0.055857  0.110
# 738  0.000614  0.042530  0.267562  0.084468  0.015
# 739  0.000300  0.002080  0.238677  0.201630  0.000
# 740  0.000012  0.000587  0.135606  0.704421  0.004
# 741  0.000089  0.000614  0.042530  0.607830  0.004
# 742  0.000223  0.000300  0.002080  0.668046  0.008
# 743  0.000037  0.000012  0.000587  0.443687  0.000
#
# [732 rows x 5 columns]

# %%
train_predict(dataframe1,10)
# Out:
# 0 Train Score: 0.179778 RMSE
# 0 Test Score: 0.222312 RMSE
# 1 Train Score: 0.167652 RMSE
# 1 Test Score: 0.215090 RMSE
# 2 Train Score: 0.175591 RMSE
# 2 Test Score: 0.226452 RMSE
# 3 Train Score: 0.199604 RMSE
# 3 Test Score: 0.215428 RMSE
# 4 Train Score: 0.179395 RMSE
# 4 Test Score: 0.210864 RMSE
# 5 Train Score: 0.176658 RMSE
# 5 Test Score: 0.217009 RMSE
# 6 Train Score: 0.160899 RMSE
# 6 Test Score: 0.221862 RMSE
# 7 Train Score: 0.185086 RMSE
# 7 Test Score: 0.207909 RMSE
# 8 Train Score: 0.184178 RMSE
# 8 Test Score: 0.254110 RMSE
# 9 Train Score: 0.171113 RMSE
# 9 Test Score: 0.212563 RMSE

# %%
window = [3,6,12,24]
dataframe1 = normalize(dataframe)
dataframe1 = create_window(dataframe1, "rad", window)
feature_dim = len(window) + 1
dataframe1
# Out:
#           rad   rad_t-3   rad_t-6  rad_t-12  rad_t-24    act
# 24   0.000000  0.000006  0.000000  0.729180  0.000000  0.019
# 25   0.000000  0.000000  0.000058  0.581848  0.000000  0.019
# 26   0.000000  0.000000  0.000012  0.339149  0.000000  0.019
# 27   0.000000  0.000000  0.000006  0.063132  0.000000  0.019
# 28   0.010967  0.000000  0.000000  0.003629  0.011469  0.019
# 29   0.038312  0.000000  0.000000  0.000000  0.048369  0.876
# 30   0.055032  0.000000  0.000000  0.000000  0.092110  1.329
# 31   0.207682  0.010967  0.000000  0.000058  0.250873  1.314
# 32   0.772584  0.038312  0.000000  0.000012  0.739878  1.433
# 33   0.928168  0.055032  0.000000  0.000006  0.892711  1.114
# 34   0.670492  0.207682  0.010967  0.000000  0.990219  0.848
# 35   0.813543  0.772584  0.038312  0.000000  0.955678  0.943
# 36   0.659793  0.928168  0.055032  0.000000  0.729180  1.095
# 37   0.314696  0.670492  0.207682  0.000000  0.581848  0.700
# 38   0.264016  0.813543  0.772584  0.000000  0.339149  0.429
# 39   0.043631  0.659793  0.928168  0.000000  0.063132  0.395
# 40   0.003012  0.314696  0.670492  0.010967  0.003629  0.438
# 41   0.000000  0.264016  0.813543  0.038312  0.000000  0.124
# 42   0.000009  0.043631  0.659793  0.055032  0.000000  0.052
# 43   0.000018  0.003012  0.314696  0.207682  0.000058  0.048
# 44   0.000000  0.000000  0.264016  0.772584  0.000012  0.043
# 45   0.000000  0.000009  0.043631  0.928168  0.000006  0.076
# 46   0.000000  0.000018  0.003012  0.670492  0.000000  0.129
# 47   0.000000  0.000000  0.000000  0.813543  0.000000  0.100
# 48   0.000000  0.000000  0.000009  0.659793  0.000000  0.064
# 49   0.000000  0.000000  0.000018  0.314696  0.000000  0.054
# 50   0.000000  0.000000  0.000000  0.264016  0.000000  0.139
# 51   0.000000  0.000000  0.000000  0.043631  0.000000  0.411
# 52   0.010472  0.000000  0.000000  0.003012  0.010967  0.639
# 53   0.037884  0.000000  0.000000  0.000000  0.038312  1.302
# ..        ...       ...       ...       ...       ...    ...
# 714  0.000000  0.035867  0.497484  0.098437  0.000000  0.087
# 715  0.000000  0.001448  0.255672  0.208202  0.000000  0.013
# 716  0.000000  0.000000  0.215385  0.750576  0.000000  0.020
# 717  0.000000  0.000000  0.035867  0.911968  0.000000  0.094
# 718  0.000000  0.000000  0.001448  0.649706  0.000000  0.087
# 719  0.000000  0.000000  0.000000  0.624336  0.000000  0.127
# 720  0.000000  0.000000  0.000000  0.497484  0.000000  0.155
# 721  0.000000  0.000000  0.000000  0.255672  0.000000  0.163
# 722  0.000000  0.000000  0.000000  0.215385  0.000000  0.167
# 723  0.000000  0.000000  0.000000  0.035867  0.000000  0.242
# 724  0.015195  0.000000  0.000000  0.001448  0.015916  0.500
# 725  0.055857  0.000000  0.000000  0.000000  0.060656  0.875
# 726  0.084468  0.000000  0.000000  0.000000  0.098437  1.352
# 727  0.201630  0.015195  0.000000  0.000000  0.208202  1.598
# 728  0.704421  0.055857  0.000000  0.000000  0.750576  2.458
# 729  0.607830  0.084468  0.000000  0.000000  0.911968  2.015
# 730  0.668046  0.201630  0.015195  0.000000  0.649706  1.280
# 731  0.443687  0.704421  0.055857  0.000000  0.624336  1.269
# 732  0.267562  0.607830  0.084468  0.000000  0.497484  1.049
# 733  0.238677  0.668046  0.201630  0.000000  0.255672  1.038
# 734  0.135606  0.443687  0.704421  0.000000  0.215385  0.648
# 735  0.042530  0.267562  0.607830  0.000000  0.035867  0.288
# 736  0.002080  0.238677  0.668046  0.015195  0.001448  0.258
# 737  0.000587  0.135606  0.443687  0.055857  0.000000  0.110
# 738  0.000614  0.042530  0.267562  0.084468  0.000000  0.015
# 739  0.000300  0.002080  0.238677  0.201630  0.000000  0.000
# 740  0.000012  0.000587  0.135606  0.704421  0.000000  0.004
# 741  0.000089  0.000614  0.042530  0.607830  0.000000  0.004
# 742  0.000223  0.000300  0.002080  0.668046  0.000000  0.008
# 743  0.000037  0.000012  0.000587  0.443687  0.000000  0.000
#
# [720 rows x 6 columns]

# %%
train_predict(dataframe1,10)
# Out:
# 0 Train Score: 0.165121 RMSE
# 0 Test Score: 0.223795 RMSE
# 1 Train Score: 0.167590 RMSE
# 1 Test Score: 0.227614 RMSE
# 2 Train Score: 0.170056 RMSE
# 2 Test Score: 0.214776 RMSE
# 3 Train Score: 0.169088 RMSE
# 3 Test Score: 0.223288 RMSE
# 4 Train Score: 0.177226 RMSE
# 4 Test Score: 0.226811 RMSE
# 5 Train Score: 0.172673 RMSE
# 5 Test Score: 0.236167 RMSE
# 6 Train Score: 0.165111 RMSE
# 6 Test Score: 0.221745 RMSE
# 7 Train Score: 0.188120 RMSE
# 7 Test Score: 0.222895 RMSE
# 8 Train Score: 0.188256 RMSE
# 8 Test Score: 0.230796 RMSE
# 9 Train Score: 0.177224 RMSE
# 9 Test Score: 0.212990 RMSE

# %%
feature_dim
# Out:
# 5
